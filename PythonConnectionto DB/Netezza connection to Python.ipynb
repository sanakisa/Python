# %%
import pandas as pd
import pyodbc

conn = pyodbc.connect("DRIVER={NetezzaSQL};SERVER=netezza16; PORT=5480;DATABASE=OPI_PRD2; UID=szehra;PWD=*******;")

cus=conn.cursor()
sql = "select * from pars_pwr.pars_odar limit 10"
DF = pd.read_sql_query(sql, conn)
DF.head()
# Out:
#   PARS_CLIENT_TYP PARS_CLIENT_NAME PARS_PLATFORM_NAME         LOB  \
# 0             UHC         EnI Core               UNET  Commercial
# 1             UHC         EnI Core               UNET  Commercial
# 2             UHC         EnI Core               UNET  Commercial
# 3             UHC         EnI Core               UNET  Commercial
# 4             UHC         EnI Core               UNET  Commercial
#
#          CLM_ID     CLM_ID_BASE       CLM_ID_FULL       UID     AUDIT_STATUS  \
# 0  685334666801  UNET6853346668  UNET685334666801  77305330      Deactivated
# 1  192388088501  UNET1923880885  UNET192388088501  14404006  Claim Committed
# 2  192349713701  UNET1923497137  UNET192349713701  14404534  Claim Committed
# 3  193262161301  UNET1932621613  UNET193262161301  14910245  Claim Committed
# 4  192048493901  UNET1920484939  UNET192048493901  14910751  Claim Committed
#
#       AUDIT_CATEGORY         ...                           PPR_FILTER  \
# 0  SYSTEM LIMITATION         ...          General Acute Care Hospital
# 1  DUPLICATE PAYMENT         ...                                 None
# 2  SYSTEM LIMITATION         ...                                 None
# 3     CONTRACT ERROR         ...                                 None
# 4  SYSTEM LIMITATION         ...                                 None
#
#   IS_OFFSHORE_RESTRICTED      ODAR_MS_ID PROV_BIL_MPIN IS_PPR_HIGH_RISK_TIN  \
# 0                      0            ORMS        227298                    1
# 1                      0          SYSTEM          None                    0
# 2                      0          SYSTEM          None                    1
# 3                      0  odarenvonshore          None                    1
# 4                      0  odarenvonshore          None                    1
#
#   REFERRAL_CODE    ADJ_NBR ODAR_BATCH_ID CRT_UHC_USER_GROUP  \
# 0          None  000226489       2819885               None
# 1          None       None        214945               None
# 2          None       None        214945               None
# 3          None       None        222527               None
# 4          None       None        222527               None
#
#               LOAD_DT
# 0 2019-12-01 19:40:43
# 1 2019-12-01 19:40:43
# 2 2019-12-01 19:40:43
# 3 2019-12-01 19:40:43
# 4 2019-12-01 19:40:43
#
# [5 rows x 223 columns]
